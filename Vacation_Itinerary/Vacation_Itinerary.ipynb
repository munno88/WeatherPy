# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps
import numpy as np

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("../Vacation_Search/WeatherPy_Vacation.csv")
vacation_df.head(100)
# Out:
#     City_ID                 City Country  Max Temp Current Description  \
# 0         3             Pacifica      US     87.06                 fog
# 1         4  Valverde Del Camino      ES     76.03           clear sky
# 2         6         Puerto Ayora      EC     70.56    scattered clouds
# 3         7              Rikitea      PF     73.78          light rain
# 4        11             Acapulco      MX     84.02       broken clouds
# ..      ...                  ...     ...       ...                 ...
# 95      229               Muisne      EC     73.94     overcast clouds
# 96      231           Amalapuram      IN     78.06     overcast clouds
# 97      232      Bambous Virieux      MU     70.05          light rain
# 98      236             Cabedelo      BR     74.07           clear sky
# 99      237              Yueyang      CN     91.81       broken clouds
#
#         Lat       Lng                                         Hotel Name
# 0   37.6138 -122.4869  Pacifica Lighthouse, Trademark Collection by W...
# 1   37.5751   -6.7543            HOTEL MONTEAROMA (ulamde hotelera S.L.)
# 2   -0.7393  -90.3518                          Finch Bay Galapagos Hotel
# 3  -23.1203 -134.9692                                    People ThankYou
# 4   16.8634  -99.8901                          HS Hotsson Smart Acapulco
# ..      ...       ...                                                ...
# 95   0.6000  -80.0333                                       Quinta Samay
# 96  16.5833   82.0167                    swayamprabha service apartments
# 97 -20.3428   57.7575                                     Casa Tia Villa
# 98  -6.9811  -34.8339                                  Pousada Camboinha
# 99  29.3333  113.0919                               Delong Fortune Hotel
#
# [100 rows x 8 columns]

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.

marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.4)
fig.add_layer(marker_layer)

# 4b. Display the figure

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
vacation_df.loc[vacation_df["Country"]=="US"]

vacation_df
# Out:
#      City_ID                 City Country  Max Temp Current Description  \
# 0          3             Pacifica      US     87.06                 fog
# 1          4  Valverde Del Camino      ES     76.03           clear sky
# 2          6         Puerto Ayora      EC     70.56    scattered clouds
# 3          7              Rikitea      PF     73.78          light rain
# 4         11             Acapulco      MX     84.02       broken clouds
# ..       ...                  ...     ...       ...                 ...
# 312      668                Mecca      SA     85.35     overcast clouds
# 313      669             Tateyama      JP     79.27     overcast clouds
# 314      670                Nador      MA     73.65    scattered clouds
# 315      672           Marsaxlokk      MT     76.08          few clouds
# 316      674           Muromtsevo      RU     74.46    scattered clouds
#
#          Lat       Lng                                         Hotel Name
# 0    37.6138 -122.4869  Pacifica Lighthouse, Trademark Collection by W...
# 1    37.5751   -6.7543            HOTEL MONTEAROMA (ulamde hotelera S.L.)
# 2    -0.7393  -90.3518                          Finch Bay Galapagos Hotel
# 3   -23.1203 -134.9692                                    People ThankYou
# 4    16.8634  -99.8901                          HS Hotsson Smart Acapulco
# ..       ...       ...                                                ...
# 312  21.4267   39.8261         Makkah Clock Royal Tower, A Fairmont Hotel
# 313  34.9833  139.8667                             Tateyama Seaside Hotel
# 314  35.1740   -2.9287                                   Hôtel La Giralda
# 315  35.8419   14.5431                                       Water's Edge
# 316  56.3724   75.2418                                 Plyazh U Reki Tara
#
# [317 rows x 8 columns]

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[vacation_df["City"]=="Salinas"]
vacation_end = vacation_df.loc[vacation_df["City"]=="Salinas"]
vacation_stop1 = vacation_df.loc[vacation_df["City"]=="Altamont"]
vacation_stop2 = vacation_df.loc[vacation_df["City"]=="Blackfoot"] 
vacation_stop3 = vacation_df.loc[vacation_df["City"]=="North Platte"]

# %%
# 6. Get the latitude-lvacation_stop3ongitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_start["Lat"].to_numpy()[0], vacation_start["Lng"].to_numpy()[0]
end = vacation_start["Lat"].to_numpy()[0], vacation_start["Lng"].to_numpy()[0]
stop1 = vacation_stop1["Lat"].to_numpy()[0], vacation_stop1["Lng"].to_numpy()[0]
stop2 = vacation_stop2["Lat"].to_numpy()[0], vacation_stop2["Lng"].to_numpy()[0]
stop3 = vacation_stop3["Lat"].to_numpy()[0], vacation_stop3["Lng"].to_numpy()[0]

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".
fig = gmaps.figure()

iti_df = gmaps.directions_layer(
    start,end, waypoints =[stop1,stop2,stop3],
    travel_mode='DRIVING')

fig.add_layer(iti_df)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start,vacation_stop1,vacation_stop2,vacation_stop3],ignore_index=True)
itinerary_df
# Out:
#    City_ID          City Country  Max Temp   Current Description      Lat  \
# 0      222       Salinas      US     81.01             clear sky  36.6777
# 1      421      Altamont      US     84.88             clear sky  42.2068
# 2      392     Blackfoot      US     83.21             clear sky  43.1905
# 3      613  North Platte      US     87.69  heavy intensity rain  41.1239
#
#         Lng                                         Hotel Name
# 0 -121.6555                     Laurel Inn & Conference Center
# 1 -121.7372     Microtel Inn & Suites by Wyndham Klamath Falls
# 2 -112.3450           Super 8 by Wyndham Blackfoot/Idaho Falls
# 3 -100.7654  Holiday Inn Express & Suites North Platte, an ...

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp} °F</dd>
</dl>

"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.

marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)

fig = gmaps.figure()
fig.add_layer(marker_layer)



# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
