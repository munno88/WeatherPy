# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.

cities = []

# Identify the nearest city for each latitude and longitude combination.

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 723

# %%
# Create an empty list to hold the weather data.

city_data = []

# Print the beginning of the logging.

print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.

record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port elizabeth
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | northam
# Processing Record 4 of Set 1 | pacifica
# Processing Record 5 of Set 1 | valverde del camino
# Processing Record 6 of Set 1 | henties bay
# Processing Record 7 of Set 1 | puerto ayora
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | beloha
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | acapulco
# Processing Record 13 of Set 1 | butaritari
# Processing Record 14 of Set 1 | locri
# Processing Record 15 of Set 1 | victoria
# Processing Record 16 of Set 1 | komsomolskiy
# Processing Record 17 of Set 1 | dikson
# Processing Record 18 of Set 1 | carnarvon
# Processing Record 19 of Set 1 | narsaq
# Processing Record 20 of Set 1 | vaini
# Processing Record 21 of Set 1 | clyde river
# Processing Record 22 of Set 1 | airai
# Processing Record 23 of Set 1 | port alfred
# Processing Record 24 of Set 1 | sibi
# Processing Record 25 of Set 1 | saint-philippe
# Processing Record 26 of Set 1 | mildura
# Processing Record 27 of Set 1 | boa vista
# Processing Record 28 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 1 | touros
# Processing Record 30 of Set 1 | deep river
# Processing Record 31 of Set 1 | ribeira grande
# Processing Record 32 of Set 1 | rajapur
# Processing Record 33 of Set 1 | zhangjiakou
# Processing Record 34 of Set 1 | champerico
# Processing Record 35 of Set 1 | esperance
# Processing Record 36 of Set 1 | sao filipe
# Processing Record 37 of Set 1 | orlik
# Processing Record 38 of Set 1 | westpunt
# City not found. Skipping...
# Processing Record 39 of Set 1 | pavlogradka
# Processing Record 40 of Set 1 | tasbuget
# City not found. Skipping...
# Processing Record 41 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 1 | punta arenas
# Processing Record 43 of Set 1 | arraial do cabo
# Processing Record 44 of Set 1 | meulaboh
# Processing Record 45 of Set 1 | bubaque
# Processing Record 46 of Set 1 | belaya gora
# Processing Record 47 of Set 1 | yulara
# Processing Record 48 of Set 1 | albany
# Processing Record 49 of Set 1 | kapaa
# Processing Record 50 of Set 1 | ngunguru
# Processing Record 1 of Set 2 | flinders
# Processing Record 2 of Set 2 | seminole
# Processing Record 3 of Set 2 | harper
# Processing Record 4 of Set 2 | donskoye
# Processing Record 5 of Set 2 | krasnouralsk
# Processing Record 6 of Set 2 | jamestown
# Processing Record 7 of Set 2 | kampot
# Processing Record 8 of Set 2 | cidreira
# Processing Record 9 of Set 2 | guerrero negro
# Processing Record 10 of Set 2 | ponta do sol
# Processing Record 11 of Set 2 | san patricio
# Processing Record 12 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 2 | bluff
# Processing Record 14 of Set 2 | soyo
# Processing Record 15 of Set 2 | tiksi
# Processing Record 16 of Set 2 | tlahualilo
# City not found. Skipping...
# Processing Record 17 of Set 2 | cockburn town
# Processing Record 18 of Set 2 | kenai
# Processing Record 19 of Set 2 | cherepovets
# Processing Record 20 of Set 2 | hilo
# Processing Record 21 of Set 2 | brandfort
# Processing Record 22 of Set 2 | gazojak
# Processing Record 23 of Set 2 | tessalit
# Processing Record 24 of Set 2 | bredasdorp
# Processing Record 25 of Set 2 | kaitangata
# Processing Record 26 of Set 2 | ketchikan
# Processing Record 27 of Set 2 | kloulklubed
# Processing Record 28 of Set 2 | castro
# Processing Record 29 of Set 2 | atambua
# Processing Record 30 of Set 2 | saint george
# Processing Record 31 of Set 2 | atuona
# Processing Record 32 of Set 2 | tiznit
# Processing Record 33 of Set 2 | mar del plata
# Processing Record 34 of Set 2 | tezu
# Processing Record 35 of Set 2 | tuktoyaktuk
# Processing Record 36 of Set 2 | zhengjiatun
# Processing Record 37 of Set 2 | ostrovnoy
# Processing Record 38 of Set 2 | wuzhou
# Processing Record 39 of Set 2 | cape town
# Processing Record 40 of Set 2 | chokurdakh
# Processing Record 41 of Set 2 | bobrov
# Processing Record 42 of Set 2 | parana
# Processing Record 43 of Set 2 | avera
# Processing Record 44 of Set 2 | constitucion
# Processing Record 45 of Set 2 | gizo
# Processing Record 46 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 2 | geraldton
# Processing Record 48 of Set 2 | yarim
# Processing Record 49 of Set 2 | ambon
# Processing Record 50 of Set 2 | khatanga
# Processing Record 1 of Set 3 | maniitsoq
# Processing Record 2 of Set 3 | georgetown
# Processing Record 3 of Set 3 | ascension
# Processing Record 4 of Set 3 | kachug
# Processing Record 5 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 3 | port blair
# Processing Record 7 of Set 3 | ancud
# Processing Record 8 of Set 3 | avarua
# Processing Record 9 of Set 3 | stokmarknes
# Processing Record 10 of Set 3 | nikolskoye
# Processing Record 11 of Set 3 | los llanos de aridane
# Processing Record 12 of Set 3 | luganville
# Processing Record 13 of Set 3 | hobart
# Processing Record 14 of Set 3 | puerto narino
# Processing Record 15 of Set 3 | thompson
# Processing Record 16 of Set 3 | hinton
# Processing Record 17 of Set 3 | chuy
# Processing Record 18 of Set 3 | dandong
# Processing Record 19 of Set 3 | upernavik
# Processing Record 20 of Set 3 | krasnoborsk
# Processing Record 21 of Set 3 | skagastrond
# City not found. Skipping...
# Processing Record 22 of Set 3 | tasiilaq
# Processing Record 23 of Set 3 | sitka
# Processing Record 24 of Set 3 | along
# Processing Record 25 of Set 3 | sorland
# Processing Record 26 of Set 3 | provideniya
# Processing Record 27 of Set 3 | novo aripuana
# Processing Record 28 of Set 3 | xining
# Processing Record 29 of Set 3 | vokhtoga
# Processing Record 30 of Set 3 | cayenne
# Processing Record 31 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 32 of Set 3 | college
# Processing Record 33 of Set 3 | vao
# Processing Record 34 of Set 3 | new norfolk
# Processing Record 35 of Set 3 | barinas
# Processing Record 36 of Set 3 | san carlos de bariloche
# Processing Record 37 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 38 of Set 3 | lorengau
# Processing Record 39 of Set 3 | krivosheino
# Processing Record 40 of Set 3 | bethel
# Processing Record 41 of Set 3 | jacareacanga
# Processing Record 42 of Set 3 | kieta
# Processing Record 43 of Set 3 | saskylakh
# Processing Record 44 of Set 3 | apatou
# Processing Record 45 of Set 3 | lebu
# Processing Record 46 of Set 3 | namibe
# Processing Record 47 of Set 3 | mwinilunga
# Processing Record 48 of Set 3 | vostok
# Processing Record 49 of Set 3 | akyab
# Processing Record 50 of Set 3 | dauriya
# Processing Record 1 of Set 4 | mandalgovi
# Processing Record 2 of Set 4 | alice springs
# Processing Record 3 of Set 4 | lavrentiya
# Processing Record 4 of Set 4 | port-gentil
# Processing Record 5 of Set 4 | tuatapere
# Processing Record 6 of Set 4 | margate
# Processing Record 7 of Set 4 | yellowknife
# Processing Record 8 of Set 4 | kruisfontein
# Processing Record 9 of Set 4 | takab
# Processing Record 10 of Set 4 | carmelo
# Processing Record 11 of Set 4 | vryburg
# Processing Record 12 of Set 4 | blagoyevo
# Processing Record 13 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 4 | dingle
# Processing Record 15 of Set 4 | dubbo
# Processing Record 16 of Set 4 | qingdao
# Processing Record 17 of Set 4 | hermanus
# Processing Record 18 of Set 4 | uaua
# Processing Record 19 of Set 4 | ust-nera
# Processing Record 20 of Set 4 | anse-bertrand
# Processing Record 21 of Set 4 | lata
# Processing Record 22 of Set 4 | tambura
# Processing Record 23 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 4 | berlevag
# Processing Record 25 of Set 4 | toora-khem
# Processing Record 26 of Set 4 | sola
# Processing Record 27 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 28 of Set 4 | dongsheng
# Processing Record 29 of Set 4 | hobyo
# Processing Record 30 of Set 4 | atar
# Processing Record 31 of Set 4 | myingyan
# Processing Record 32 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 4 | carutapera
# Processing Record 34 of Set 4 | khudumelapye
# Processing Record 35 of Set 4 | krasnoselkup
# Processing Record 36 of Set 4 | kudahuvadhoo
# Processing Record 37 of Set 4 | podyuga
# Processing Record 38 of Set 4 | mount isa
# Processing Record 39 of Set 4 | port hedland
# Processing Record 40 of Set 4 | hengelo
# Processing Record 41 of Set 4 | krasnotorka
# Processing Record 42 of Set 4 | hukuntsi
# Processing Record 43 of Set 4 | pevek
# Processing Record 44 of Set 4 | marawi
# Processing Record 45 of Set 4 | lagoa
# Processing Record 46 of Set 4 | khlung
# Processing Record 47 of Set 4 | ahipara
# Processing Record 48 of Set 4 | sosnovka
# Processing Record 49 of Set 4 | grindavik
# Processing Record 50 of Set 4 | nyurba
# Processing Record 1 of Set 5 | liverpool
# Processing Record 2 of Set 5 | okha
# Processing Record 3 of Set 5 | nemuro
# Processing Record 4 of Set 5 | vila franca do campo
# Processing Record 5 of Set 5 | santa cruz
# Processing Record 6 of Set 5 | alofi
# Processing Record 7 of Set 5 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 8 of Set 5 | illela
# Processing Record 9 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 5 | vila velha
# Processing Record 11 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 5 | verkhnyaya inta
# Processing Record 13 of Set 5 | raudeberg
# Processing Record 14 of Set 5 | calvinia
# Processing Record 15 of Set 5 | erenhot
# Processing Record 16 of Set 5 | lydenburg
# Processing Record 17 of Set 5 | port shepstone
# Processing Record 18 of Set 5 | sarkand
# Processing Record 19 of Set 5 | puro
# Processing Record 20 of Set 5 | les cayes
# Processing Record 21 of Set 5 | huarmey
# Processing Record 22 of Set 5 | sarmizegetusa
# Processing Record 23 of Set 5 | minab
# Processing Record 24 of Set 5 | kavaratti
# Processing Record 25 of Set 5 | souillac
# Processing Record 26 of Set 5 | katsuura
# Processing Record 27 of Set 5 | kodiak
# Processing Record 28 of Set 5 | east london
# Processing Record 29 of Set 5 | omboue
# Processing Record 30 of Set 5 | biltine
# Processing Record 31 of Set 5 | santiago del estero
# Processing Record 32 of Set 5 | khairabad
# Processing Record 33 of Set 5 | la brea
# Processing Record 34 of Set 5 | scarborough
# Processing Record 35 of Set 5 | imeni poliny osipenko
# Processing Record 36 of Set 5 | port moresby
# Processing Record 37 of Set 5 | willmar
# Processing Record 38 of Set 5 | barabinsk
# Processing Record 39 of Set 5 | hirara
# Processing Record 40 of Set 5 | barrow
# Processing Record 41 of Set 5 | salinas
# Processing Record 42 of Set 5 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 43 of Set 5 | cap malheureux
# Processing Record 44 of Set 5 | awjilah
# Processing Record 45 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 5 | bengkulu
# Processing Record 47 of Set 5 | sept-iles
# Processing Record 48 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 5 | svetlogorsk
# Processing Record 50 of Set 5 | ayios nikolaos
# Processing Record 1 of Set 6 | muisne
# Processing Record 2 of Set 6 | lobva
# Processing Record 3 of Set 6 | amalapuram
# Processing Record 4 of Set 6 | bambous virieux
# Processing Record 5 of Set 6 | haines junction
# Processing Record 6 of Set 6 | ferme-neuve
# Processing Record 7 of Set 6 | ambanja
# Processing Record 8 of Set 6 | cabedelo
# Processing Record 9 of Set 6 | yueyang
# Processing Record 10 of Set 6 | robertsport
# Processing Record 11 of Set 6 | san rafael del sur
# Processing Record 12 of Set 6 | cayhagan
# Processing Record 13 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 14 of Set 6 | kahului
# Processing Record 15 of Set 6 | minbu
# Processing Record 16 of Set 6 | kurush
# Processing Record 17 of Set 6 | chimbote
# Processing Record 18 of Set 6 | egvekinot
# Processing Record 19 of Set 6 | loubomo
# Processing Record 20 of Set 6 | gbadolite
# Processing Record 21 of Set 6 | jambi
# Processing Record 22 of Set 6 | kamenka
# Processing Record 23 of Set 6 | walvis bay
# Processing Record 24 of Set 6 | kindu
# Processing Record 25 of Set 6 | ilulissat
# Processing Record 26 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 27 of Set 6 | staryy merchyk
# Processing Record 28 of Set 6 | bolshaya dzhalga
# Processing Record 29 of Set 6 | kokopo
# Processing Record 30 of Set 6 | komatipoort
# Processing Record 31 of Set 6 | hasaki
# Processing Record 32 of Set 6 | brae
# Processing Record 33 of Set 6 | isangel
# Processing Record 34 of Set 6 | aitape
# Processing Record 35 of Set 6 | klang
# Processing Record 36 of Set 6 | naze
# Processing Record 37 of Set 6 | margherita
# Processing Record 38 of Set 6 | canmore
# Processing Record 39 of Set 6 | shahr-e babak
# Processing Record 40 of Set 6 | mutoko
# Processing Record 41 of Set 6 | yarkovo
# Processing Record 42 of Set 6 | ratnagiri
# Processing Record 43 of Set 6 | paamiut
# Processing Record 44 of Set 6 | la joya
# Processing Record 45 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 6 | bosaso
# Processing Record 47 of Set 6 | mahibadhoo
# Processing Record 48 of Set 6 | inhambane
# Processing Record 49 of Set 6 | suntar
# Processing Record 50 of Set 6 | oktyabrskiy
# Processing Record 1 of Set 7 | tual
# Processing Record 2 of Set 7 | gat
# Processing Record 3 of Set 7 | betare oya
# Processing Record 4 of Set 7 | severo-kurilsk
# Processing Record 5 of Set 7 | camacha
# Processing Record 6 of Set 7 | tuensang
# Processing Record 7 of Set 7 | warrnambool
# Processing Record 8 of Set 7 | moranbah
# Processing Record 9 of Set 7 | nauta
# Processing Record 10 of Set 7 | gazanjyk
# Processing Record 11 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 12 of Set 7 | norman wells
# Processing Record 13 of Set 7 | sibu
# Processing Record 14 of Set 7 | chapais
# Processing Record 15 of Set 7 | natal
# Processing Record 16 of Set 7 | kavieng
# Processing Record 17 of Set 7 | am timan
# Processing Record 18 of Set 7 | lahaina
# Processing Record 19 of Set 7 | kaduqli
# Processing Record 20 of Set 7 | mnogovershinnyy
# Processing Record 21 of Set 7 | onda
# Processing Record 22 of Set 7 | khorramshahr
# Processing Record 23 of Set 7 | manica
# Processing Record 24 of Set 7 | broome
# Processing Record 25 of Set 7 | novouzensk
# Processing Record 26 of Set 7 | karoi
# Processing Record 27 of Set 7 | bodden town
# Processing Record 28 of Set 7 | vardo
# Processing Record 29 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 7 | riachao
# Processing Record 31 of Set 7 | pandan
# Processing Record 32 of Set 7 | rocha
# Processing Record 33 of Set 7 | sattahip
# Processing Record 34 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 7 | jalu
# Processing Record 36 of Set 7 | nkan
# Processing Record 37 of Set 7 | kabalo
# Processing Record 38 of Set 7 | tautira
# Processing Record 39 of Set 7 | codrington
# Processing Record 40 of Set 7 | richards bay
# Processing Record 41 of Set 7 | aklavik
# Processing Record 42 of Set 7 | anadyr
# Processing Record 43 of Set 7 | stornoway
# Processing Record 44 of Set 7 | okmulgee
# Processing Record 45 of Set 7 | lingao
# Processing Record 46 of Set 7 | karratha
# Processing Record 47 of Set 7 | hualmay
# Processing Record 48 of Set 7 | jardim
# Processing Record 49 of Set 7 | salalah
# Processing Record 50 of Set 7 | santa maria
# Processing Record 1 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 8 | bama
# Processing Record 3 of Set 8 | lompoc
# Processing Record 4 of Set 8 | presidencia roque saenz pena
# Processing Record 5 of Set 8 | ballina
# Processing Record 6 of Set 8 | tilichiki
# Processing Record 7 of Set 8 | bata
# Processing Record 8 of Set 8 | santiago
# Processing Record 9 of Set 8 | kemin
# Processing Record 10 of Set 8 | rio branco
# Processing Record 11 of Set 8 | coquimbo
# Processing Record 12 of Set 8 | shwebo
# Processing Record 13 of Set 8 | ust-omchug
# Processing Record 14 of Set 8 | aykhal
# Processing Record 15 of Set 8 | obihiro
# Processing Record 16 of Set 8 | bonfim
# Processing Record 17 of Set 8 | bilibino
# Processing Record 18 of Set 8 | ye
# City not found. Skipping...
# Processing Record 19 of Set 8 | cherskiy
# Processing Record 20 of Set 8 | mahebourg
# Processing Record 21 of Set 8 | general pico
# Processing Record 22 of Set 8 | toktogul
# Processing Record 23 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 8 | pio xii
# Processing Record 25 of Set 8 | sexsmith
# Processing Record 26 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 27 of Set 8 | nabire
# Processing Record 28 of Set 8 | ipeti
# City not found. Skipping...
# Processing Record 29 of Set 8 | fortuna
# Processing Record 30 of Set 8 | hambantota
# Processing Record 31 of Set 8 | ravar
# Processing Record 32 of Set 8 | talnakh
# Processing Record 33 of Set 8 | lensk
# Processing Record 34 of Set 8 | naantali
# Processing Record 35 of Set 8 | roebourne
# Processing Record 36 of Set 8 | jackson
# Processing Record 37 of Set 8 | menongue
# Processing Record 38 of Set 8 | jashpurnagar
# Processing Record 39 of Set 8 | podor
# Processing Record 40 of Set 8 | kushiro
# Processing Record 41 of Set 8 | ixtapa
# Processing Record 42 of Set 8 | gaya
# Processing Record 43 of Set 8 | san jeronimo
# Processing Record 44 of Set 8 | trincomalee
# Processing Record 45 of Set 8 | bolanos de calatrava
# Processing Record 46 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 47 of Set 8 | farah
# Processing Record 48 of Set 8 | bathsheba
# Processing Record 49 of Set 8 | isabela
# Processing Record 50 of Set 8 | taltal
# Processing Record 1 of Set 9 | yerbogachen
# Processing Record 2 of Set 9 | elizabeth city
# Processing Record 3 of Set 9 | manjacaze
# Processing Record 4 of Set 9 | pokhara
# Processing Record 5 of Set 9 | aracati
# Processing Record 6 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 7 of Set 9 | portland
# Processing Record 8 of Set 9 | manzil salim
# Processing Record 9 of Set 9 | fuxin
# Processing Record 10 of Set 9 | warmbad
# Processing Record 11 of Set 9 | punjai puliyampatti
# Processing Record 12 of Set 9 | svay rieng
# Processing Record 13 of Set 9 | te anau
# Processing Record 14 of Set 9 | hernani
# Processing Record 15 of Set 9 | ugoofaaru
# Processing Record 16 of Set 9 | huescar
# Processing Record 17 of Set 9 | gusau
# Processing Record 18 of Set 9 | tala
# Processing Record 19 of Set 9 | taiobeiras
# Processing Record 20 of Set 9 | straumen
# Processing Record 21 of Set 9 | bundaberg
# Processing Record 22 of Set 9 | umm lajj
# Processing Record 23 of Set 9 | tshane
# Processing Record 24 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 25 of Set 9 | sao joao da barra
# Processing Record 26 of Set 9 | buraydah
# Processing Record 27 of Set 9 | blackfoot
# Processing Record 28 of Set 9 | torbay
# Processing Record 29 of Set 9 | nioro
# Processing Record 30 of Set 9 | leh
# Processing Record 31 of Set 9 | sladkovo
# Processing Record 32 of Set 9 | three hills
# Processing Record 33 of Set 9 | mao
# Processing Record 34 of Set 9 | doha
# Processing Record 35 of Set 9 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 36 of Set 9 | qaanaaq
# Processing Record 37 of Set 9 | prince rupert
# Processing Record 38 of Set 9 | evensk
# Processing Record 39 of Set 9 | hofn
# Processing Record 40 of Set 9 | saint-augustin
# Processing Record 41 of Set 9 | toftir
# City not found. Skipping...
# Processing Record 42 of Set 9 | hithadhoo
# Processing Record 43 of Set 9 | zachagansk
# City not found. Skipping...
# Processing Record 44 of Set 9 | nouadhibou
# Processing Record 45 of Set 9 | maltahohe
# Processing Record 46 of Set 9 | himora
# City not found. Skipping...
# Processing Record 47 of Set 9 | ambovombe
# Processing Record 48 of Set 9 | la asuncion
# Processing Record 49 of Set 9 | puerto baquerizo moreno
# Processing Record 50 of Set 9 | iqaluit
# Processing Record 1 of Set 10 | ibia
# Processing Record 2 of Set 10 | shirwal
# Processing Record 3 of Set 10 | faanui
# Processing Record 4 of Set 10 | shikohabad
# Processing Record 5 of Set 10 | khandyga
# Processing Record 6 of Set 10 | lakatoro
# Processing Record 7 of Set 10 | romny
# Processing Record 8 of Set 10 | yatou
# Processing Record 9 of Set 10 | imbituba
# Processing Record 10 of Set 10 | altamont
# Processing Record 11 of Set 10 | bardiyah
# Processing Record 12 of Set 10 | johnstown
# Processing Record 13 of Set 10 | sisimiut
# Processing Record 14 of Set 10 | fort nelson
# Processing Record 15 of Set 10 | chabahar
# Processing Record 16 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 17 of Set 10 | chichica
# Processing Record 18 of Set 10 | siguiri
# Processing Record 19 of Set 10 | port hardy
# Processing Record 20 of Set 10 | ibotirama
# Processing Record 21 of Set 10 | eureka
# Processing Record 22 of Set 10 | ust-kuyga
# Processing Record 23 of Set 10 | san julian
# Processing Record 24 of Set 10 | rudbar
# Processing Record 25 of Set 10 | oga
# Processing Record 26 of Set 10 | russell
# Processing Record 27 of Set 10 | lysa hora
# Processing Record 28 of Set 10 | paluan
# Processing Record 29 of Set 10 | half moon bay
# Processing Record 30 of Set 10 | lattes
# Processing Record 31 of Set 10 | palasa
# Processing Record 32 of Set 10 | sokolo
# Processing Record 33 of Set 10 | lodja
# Processing Record 34 of Set 10 | diego de almagro
# Processing Record 35 of Set 10 | muros
# Processing Record 36 of Set 10 | sarangani
# Processing Record 37 of Set 10 | paka
# Processing Record 38 of Set 10 | kalnibolotskaya
# Processing Record 39 of Set 10 | porto novo
# Processing Record 40 of Set 10 | bonavista
# Processing Record 41 of Set 10 | ayan
# Processing Record 42 of Set 10 | seymchan
# Processing Record 43 of Set 10 | mirina
# City not found. Skipping...
# Processing Record 44 of Set 10 | sambava
# Processing Record 45 of Set 10 | tecoanapa
# Processing Record 46 of Set 10 | sal rei
# Processing Record 47 of Set 10 | tura
# Processing Record 48 of Set 10 | nanortalik
# Processing Record 49 of Set 10 | sinnamary
# Processing Record 50 of Set 10 | rosetta
# Processing Record 1 of Set 11 | pundaguitan
# Processing Record 2 of Set 11 | sakakah
# Processing Record 3 of Set 11 | mardan
# Processing Record 4 of Set 11 | kawalu
# Processing Record 5 of Set 11 | aquiraz
# Processing Record 6 of Set 11 | timra
# Processing Record 7 of Set 11 | puerto parra
# Processing Record 8 of Set 11 | byron bay
# Processing Record 9 of Set 11 | concarneau
# Processing Record 10 of Set 11 | qaqortoq
# Processing Record 11 of Set 11 | solnechnyy
# Processing Record 12 of Set 11 | sampit
# Processing Record 13 of Set 11 | yarmouth
# Processing Record 14 of Set 11 | nuuk
# Processing Record 15 of Set 11 | coruripe
# Processing Record 16 of Set 11 | cabo san lucas
# Processing Record 17 of Set 11 | venado tuerto
# Processing Record 18 of Set 11 | sozimskiy
# Processing Record 19 of Set 11 | noumea
# Processing Record 20 of Set 11 | matay
# Processing Record 21 of Set 11 | kirakira
# Processing Record 22 of Set 11 | morro bay
# Processing Record 23 of Set 11 | brokopondo
# Processing Record 24 of Set 11 | kaputa
# Processing Record 25 of Set 11 | lienz
# Processing Record 26 of Set 11 | adre
# Processing Record 27 of Set 11 | klaksvik
# Processing Record 28 of Set 11 | jieshi
# Processing Record 29 of Set 11 | aguilas
# Processing Record 30 of Set 11 | longkou
# Processing Record 31 of Set 11 | yaan
# Processing Record 32 of Set 11 | tabou
# Processing Record 33 of Set 11 | belyy yar
# Processing Record 34 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 35 of Set 11 | pasighat
# Processing Record 36 of Set 11 | narrabri
# Processing Record 37 of Set 11 | varhaug
# Processing Record 38 of Set 11 | uribia
# Processing Record 39 of Set 11 | saint anthony
# Processing Record 40 of Set 11 | colares
# Processing Record 41 of Set 11 | leningradskiy
# Processing Record 42 of Set 11 | goderich
# Processing Record 43 of Set 11 | tecpan
# Processing Record 44 of Set 11 | akdepe
# Processing Record 45 of Set 11 | volchikha
# Processing Record 46 of Set 11 | tabriz
# Processing Record 47 of Set 11 | hovd
# Processing Record 48 of Set 11 | port lincoln
# Processing Record 49 of Set 11 | sistranda
# Processing Record 50 of Set 11 | leeuwarden
# Processing Record 1 of Set 12 | srivardhan
# Processing Record 2 of Set 12 | grand gaube
# Processing Record 3 of Set 12 | tondela
# Processing Record 4 of Set 12 | muscat
# Processing Record 5 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 6 of Set 12 | teya
# Processing Record 7 of Set 12 | fagernes
# Processing Record 8 of Set 12 | tabas
# Processing Record 9 of Set 12 | aboso
# Processing Record 10 of Set 12 | fort-shevchenko
# Processing Record 11 of Set 12 | tsabong
# Processing Record 12 of Set 12 | bathurst
# Processing Record 13 of Set 12 | flin flon
# Processing Record 14 of Set 12 | bijie
# Processing Record 15 of Set 12 | bontang
# Processing Record 16 of Set 12 | gvarv
# Processing Record 17 of Set 12 | general roca
# Processing Record 18 of Set 12 | shimoda
# Processing Record 19 of Set 12 | sturovo
# Processing Record 20 of Set 12 | okhotsk
# Processing Record 21 of Set 12 | juneau
# Processing Record 22 of Set 12 | coffs harbour
# Processing Record 23 of Set 12 | saldanha
# Processing Record 24 of Set 12 | poum
# Processing Record 25 of Set 12 | borzya
# Processing Record 26 of Set 12 | lerwick
# Processing Record 27 of Set 12 | sao jose da coroa grande
# Processing Record 28 of Set 12 | tynda
# Processing Record 29 of Set 12 | bhavnagar
# Processing Record 30 of Set 12 | shitanjing
# Processing Record 31 of Set 12 | kijang
# Processing Record 32 of Set 12 | hirado
# Processing Record 33 of Set 12 | peleduy
# Processing Record 34 of Set 12 | maceio
# Processing Record 35 of Set 12 | ola
# Processing Record 36 of Set 12 | mbini
# Processing Record 37 of Set 12 | rincon
# Processing Record 38 of Set 12 | pryozerne
# Processing Record 39 of Set 12 | cumaribo
# City not found. Skipping...
# Processing Record 40 of Set 12 | colac
# Processing Record 41 of Set 12 | severodvinsk
# Processing Record 42 of Set 12 | corinth
# Processing Record 43 of Set 12 | perafita
# Processing Record 44 of Set 12 | novikovo
# Processing Record 45 of Set 12 | hami
# Processing Record 46 of Set 12 | manoel urbano
# Processing Record 47 of Set 12 | rodrigues alves
# Processing Record 48 of Set 12 | villa carlos paz
# Processing Record 49 of Set 12 | kununurra
# Processing Record 50 of Set 12 | longyearbyen
# Processing Record 1 of Set 13 | asau
# Processing Record 2 of Set 13 | olinda
# Processing Record 3 of Set 13 | zhigansk
# Processing Record 4 of Set 13 | abu kamal
# Processing Record 5 of Set 13 | tshikapa
# Processing Record 6 of Set 13 | kampene
# Processing Record 7 of Set 13 | oktyabrskoye
# Processing Record 8 of Set 13 | rafiganj
# Processing Record 9 of Set 13 | vuktyl
# Processing Record 10 of Set 13 | visnes
# Processing Record 11 of Set 13 | sovetskiy
# Processing Record 12 of Set 13 | hay river
# Processing Record 13 of Set 13 | sri aman
# Processing Record 14 of Set 13 | dwarka
# Processing Record 15 of Set 13 | yumen
# Processing Record 16 of Set 13 | alyangula
# Processing Record 17 of Set 13 | maldonado
# Processing Record 18 of Set 13 | iquique
# Processing Record 19 of Set 13 | marsa matruh
# Processing Record 20 of Set 13 | praia da vitoria
# Processing Record 21 of Set 13 | mitsamiouli
# Processing Record 22 of Set 13 | sungaipenuh
# Processing Record 23 of Set 13 | khash
# Processing Record 24 of Set 13 | chapada dos guimaraes
# Processing Record 25 of Set 13 | lai
# Processing Record 26 of Set 13 | linhares
# Processing Record 27 of Set 13 | grimari
# City not found. Skipping...
# Processing Record 28 of Set 13 | veraval
# Processing Record 29 of Set 13 | kangaatsiaq
# Processing Record 30 of Set 13 | la roda
# Processing Record 31 of Set 13 | saint-leu
# Processing Record 32 of Set 13 | caconda
# Processing Record 33 of Set 13 | celestun
# Processing Record 34 of Set 13 | westport
# Processing Record 35 of Set 13 | urubamba
# Processing Record 36 of Set 13 | duayaw nkwanta
# Processing Record 37 of Set 13 | mount gambier
# Processing Record 38 of Set 13 | shanghai
# Processing Record 39 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 13 | nome
# Processing Record 41 of Set 13 | yen bai
# Processing Record 42 of Set 13 | zeya
# Processing Record 43 of Set 13 | mayumba
# Processing Record 44 of Set 13 | vitimskiy
# City not found. Skipping...
# Processing Record 45 of Set 13 | broken hill
# Processing Record 46 of Set 13 | viedma
# Processing Record 47 of Set 13 | palana
# Processing Record 48 of Set 13 | yashkul
# Processing Record 49 of Set 13 | buala
# Processing Record 50 of Set 13 | olafsvik
# Processing Record 1 of Set 14 | sunbury
# Processing Record 2 of Set 14 | mayo
# Processing Record 3 of Set 14 | buariki
# City not found. Skipping...
# Processing Record 4 of Set 14 | gravdal
# Processing Record 5 of Set 14 | chicama
# Processing Record 6 of Set 14 | caravelas
# Processing Record 7 of Set 14 | ladario
# Processing Record 8 of Set 14 | san miguel
# Processing Record 9 of Set 14 | buin
# Processing Record 10 of Set 14 | yangambi
# Processing Record 11 of Set 14 | north platte
# Processing Record 12 of Set 14 | laguna
# Processing Record 13 of Set 14 | emerald
# Processing Record 14 of Set 14 | tucuman
# Processing Record 15 of Set 14 | aguimes
# Processing Record 16 of Set 14 | afrikanda
# Processing Record 17 of Set 14 | kenitra
# Processing Record 18 of Set 14 | manicore
# Processing Record 19 of Set 14 | kutum
# Processing Record 20 of Set 14 | lasa
# Processing Record 21 of Set 14 | nara
# Processing Record 22 of Set 14 | pimentel
# Processing Record 23 of Set 14 | kidal
# Processing Record 24 of Set 14 | banjar
# Processing Record 25 of Set 14 | rio grande
# Processing Record 26 of Set 14 | luderitz
# Processing Record 27 of Set 14 | perbaungan
# Processing Record 28 of Set 14 | madera
# Processing Record 29 of Set 14 | nizhnyaya omka
# Processing Record 30 of Set 14 | namatanai
# Processing Record 31 of Set 14 | manbij
# Processing Record 32 of Set 14 | guaruja
# Processing Record 33 of Set 14 | ruston
# Processing Record 34 of Set 14 | de aar
# Processing Record 35 of Set 14 | joshimath
# Processing Record 36 of Set 14 | la ronge
# Processing Record 37 of Set 14 | sao goncalo do amarante
# Processing Record 38 of Set 14 | alto baudo
# City not found. Skipping...
# Processing Record 39 of Set 14 | hatsukaichi
# Processing Record 40 of Set 14 | sarh
# Processing Record 41 of Set 14 | plesetsk
# Processing Record 42 of Set 14 | willowmore
# Processing Record 43 of Set 14 | quthing
# Processing Record 44 of Set 14 | gimbi
# Processing Record 45 of Set 14 | yorosso
# Processing Record 46 of Set 14 | batemans bay
# Processing Record 47 of Set 14 | araouane
# Processing Record 48 of Set 14 | hokitika
# Processing Record 49 of Set 14 | nsanje
# Processing Record 50 of Set 14 | mackay
# Processing Record 1 of Set 15 | khani
# Processing Record 2 of Set 15 | curitibanos
# Processing Record 3 of Set 15 | tikrit
# Processing Record 4 of Set 15 | delvine
# Processing Record 5 of Set 15 | olga
# Processing Record 6 of Set 15 | poltavka
# Processing Record 7 of Set 15 | mongoumba
# Processing Record 8 of Set 15 | bethanien
# Processing Record 9 of Set 15 | taupo
# Processing Record 10 of Set 15 | bella vista
# Processing Record 11 of Set 15 | kalmunai
# Processing Record 12 of Set 15 | dicabisagan
# Processing Record 13 of Set 15 | ankola
# Processing Record 14 of Set 15 | murakami
# Processing Record 15 of Set 15 | srandakan
# Processing Record 16 of Set 15 | christchurch
# Processing Record 17 of Set 15 | mecca
# Processing Record 18 of Set 15 | tateyama
# Processing Record 19 of Set 15 | nador
# Processing Record 20 of Set 15 | nexo
# Processing Record 21 of Set 15 | marsaxlokk
# Processing Record 22 of Set 15 | holme
# Processing Record 23 of Set 15 | muromtsevo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Port Elizabeth -33.9180   25.5701     54.32        87          20
# 1            Busselton -33.6500  115.3333     57.54        64          81
# 2              Northam  51.0333   -4.2167     61.39        88           0
# 3             Pacifica  37.6138 -122.4869     87.06        87          20
# 4  Valverde Del Camino  37.5751   -6.7543     76.03        33           0
# 5          Henties Bay -22.1160   14.2845     53.80        89           0
# 6         Puerto Ayora  -0.7393  -90.3518     70.56        93          34
# 7              Rikitea -23.1203 -134.9692     73.78        77           0
# 8              Mataura -46.1927  168.8643     44.44        65         100
# 9               Beloha -25.1667   45.0500     60.57        71           0
#
#    Wind Speed Country Current Description
# 0       13.00      ZA          few clouds
# 1        6.17      AU       broken clouds
# 2        5.55      GB           clear sky
# 3       14.97      US                 fog
# 4        4.25      ES           clear sky
# 5        9.35      NA           clear sky
# 6        5.99      EC    scattered clouds
# 7        6.71      PF          light rain
# 8        4.63      NZ     overcast clouds
# 9        6.11      MG           clear sky

# %%
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]

city_data_df = city_data_df[new_column_order]


city_data_df.head()
# Out:
#                   City Country      Lat       Lng  Max Temp  Humidity  \
# 0       Port Elizabeth      ZA -33.9180   25.5701     54.32        87
# 1            Busselton      AU -33.6500  115.3333     57.54        64
# 2              Northam      GB  51.0333   -4.2167     61.39        88
# 3             Pacifica      US  37.6138 -122.4869     87.06        87
# 4  Valverde Del Camino      ES  37.5751   -6.7543     76.03        33
#
#    Cloudiness  Wind Speed Current Description
# 0          20       13.00          few clouds
# 1          81        6.17       broken clouds
# 2           0        5.55           clear sky
# 3          20       14.97                 fog
# 4           0        4.25           clear sky

# %%
# Create the output file (CSV).

output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.

city_data_df.to_csv(output_data_file, index_label="City_ID")
